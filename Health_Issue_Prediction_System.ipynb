# %% [markdown]
# <a href="https://colab.research.google.com/github/23kq1a5413-ai/Calculator-Program/blob/main/Health_Issue_Prediction_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Health Issue Prediction System (Rule Based) – FULL VERSION

def predict_disease(symptoms):
    s = symptoms.lower()

    if "wheezing" in s and "shortness of breath" in s:
        return "Asthma"
    elif "weakness" in s and "pale skin" in s:
        return "Anemia"
    elif "joint pain" in s and "swelling" in s:
        return "Arthritis"
    elif "memory loss" in s and "confusion" in s:
        return "Alzheimer’s Disease"

    elif "chest pain" in s and "shortness of breath" in s:
        return "Heart Attack"
    elif "cough" in s and "mucus" in s:
        return "Bronchitis"
    elif "fits" in s or "seizures" in s:
        return "Brain Disorder (Epilepsy)"

    elif "runny nose" in s and "sneezing" in s:
        return "Common Cold"
    elif "weight loss" in s and "lump" in s:
        return "Cancer"
    elif "hard stools" in s and "stomach pain" in s:
        return "Constipation"
    elif "fever" in s and "itchy blisters" in s:
        return "Chickenpox"

    elif "frequent urination" in s and "thirst" in s:
        return "Diabetes"
    elif "high fever" in s and "severe body pain" in s:
        return "Dengue"
    elif "sadness" in s and "loss of interest" in s:
        return "Depression"

    elif "ear pain" in s and "hearing problem" in s:
        return "Ear Infection"

    elif "fever" in s and "body pain" in s:
        return "Flu"
    elif "vomiting" in s and "diarrhea" in s:
        return "Food Poisoning"

    elif "stomach pain" in s and "bloating" in s:
        return "Gastritis"
    elif "joint pain" in s and "redness" in s:
        return "Gout"

    elif "high bp" in s or "high blood pressure" in s:
        return "High Blood Pressure"
    elif "irregular heartbeat" in s and "dizziness" in s:
        return "Heart Arrhythmia"

    elif "sleeplessness" in s:
        return "Insomnia"

    elif "yellow eyes" in s and "dark urine" in s:
        return "Jaundice"

    elif "back pain" in s and "pain while urinating" in s:
        return "Kidney Stones"
    elif "less urine" in s and "swelling" in s:
        return "Kidney Failure"

    elif "abdominal pain" in s and "jaundice" in s:
        return "Liver Disease"

    elif "fever with chills" in s:
        return "Malaria"
    elif "severe headache" in s and "light sensitivity" in s:
        return "Migraine"
    elif "fever" in s and "rash" in s and "cough" in s:
        return "Measles"

    elif "vomiting feeling" in s:
        return "Nausea"

    elif "excess weight" in s:
        return "Obesity"
    elif "bone pain" in s:
        return "Osteoporosis"

    elif "cough" in s and "chest pain" in s and "fever" in s:
        return "Pneumonia"
    elif "irregular periods" in s and "weight gain" in s:
        return "PCOS / PCOD"
    elif "loss of movement" in s:
        return "Paralysis"

    elif "fever" in s and "muscle pain" in s:
        return "Q Fever"

    elif "itchy circular rash" in s:
        return "Ringworm"

    elif "sudden weakness" in s or "speech problem" in s:
        return "Brain Stroke"
    elif "fear" in s and "fast heartbeat" in s:
        return "Anxiety"
    elif "face pain" in s and "blocked nose" in s:
        return "Sinusitis"

    elif "long cough" in s and "weight loss" in s:
        return "Tuberculosis"
    elif "weight change" in s and "hair fall" in s:
        return "Thyroid Disorder"
    elif "muscle stiffness" in s and "jaw lock" in s:
        return "Tetanus"

    elif "burning while urinating" in s:
        return "Urinary Tract Infection"

    elif "viral infection" in s:
        return "Viral Fever"
    elif "spinning sensation" in s:
        return "Vertigo"

    elif "whistling sound while breathing" in s:
        return "Wheezing Disorder"

    elif "dry skin" in s:
        return "Xeroderma"

    elif "itching" in s and "white discharge" in s:
        return "Yeast Infection"

    elif "rash" in s and "joint pain" in s:
        return "Zika Virus"

    else:
        return "Disease not identified. Please consult a doctor."


# -------- Medicine & Doctor Database --------

medicine_data = {
    "Asthma": "Inhaler, Avoid dust, Consult Pulmonologist",
    "Anemia": "Iron supplements, Iron-rich food",
    "Arthritis": "Pain relievers, Physiotherapy",
    "Heart Attack": "Emergency care immediately",
    "Common Cold": "Rest, Steam inhalation, Paracetamol",
    "Flu": "Paracetamol, Fluids, Rest",
    "Diabetes": "Insulin / Metformin (Doctor advice required)",
    "Dengue": "Paracetamol, Hydration, Platelet monitoring",
    "Migraine": "Pain relievers, Dark room rest",
    "Malaria": "Antimalarial drugs",
    "Pneumonia": "Antibiotics (Doctor consultation)",
    "Urinary Tract Infection": "Antibiotics, Drink water",
    "Sinusitis": "Steam inhalation, Decongestants",
    "Tuberculosis": "TB antibiotic course (6 months)",
    "Vertigo": "Balance therapy, Medication",
    "Viral Fever": "Paracetamol, Rest, Fluids"
}

doctor_data = {
    "Asthma": "Dr. Ramesh – Pulmonologist – 9876543210",
    "Diabetes": "Dr. Priya – Endocrinologist – 9876501234",
    "Heart Attack": "Dr. Arun – Cardiologist – 9123456780",
    "Migraine": "Dr. Kavya – Neurologist – 9988776655",
    "Pneumonia": "Dr. Sameer – Chest Specialist – 9012345678",
    "Urinary Tract Infection": "Dr. Neha – General Physician – 9001122334"
}

# -------- MAIN --------

print("Health Issue Prediction System (Full Version)")
user_input = input("Enter symptoms (comma separated): ")

disease = predict_disease(user_input)

print("\n🩺 Predicted Health Issue:", disease)

if disease in medicine_data:
    print("💊 Suggested Medicine:", medicine_data[disease])
else:
    print("💊 Medicine: Please consult doctor for proper prescription.")

if disease in doctor_data:
    print("👨‍⚕️ Doctor Contact:", doctor_data[disease])
else:
    print("👨‍⚕️ Doctor: Visit nearest hospital for further diagnosis.")
# Out:
# Health Issue Prediction System (Full Version)
# Enter symptoms (comma separated): fever , body pains
#
# 🩺 Predicted Health Issue: Flu
# 💊 Suggested Medicine: Paracetamol, Fluids, Rest
# 👨‍⚕️ Doctor: Visit nearest hospital for further diagnosis.
